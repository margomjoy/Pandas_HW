# %% [markdown]
# ## Python Mini-Project: Data Clean-Up, Pt. 2
#
# Pay close attention to the prompts to help guide you through this task.

# %%
# Dependencies
import pandas as pd

# %%
# load CSV
df = pd.read_csv("Resources/2016-FCC-New-Coders-Survey-Data.csv")

# %%
# Read with pandas--low_memory required to suppress errors about mixed data types
# You may need to encode this file
df.head()
# Out:
#     Age  AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 0  28.0               0.0             NaN                   NaN
# 1  22.0               0.0             NaN                   NaN
# 2  19.0               0.0             NaN                   NaN
# 3  26.0               0.0             NaN                   NaN
# 4  20.0               0.0             NaN                   NaN
#
#    BootcampLoanYesNo  BootcampMonthsAgo BootcampName  BootcampPostSalary  \
# 0                NaN                NaN          NaN                 NaN
# 1                NaN                NaN          NaN                 NaN
# 2                NaN                NaN          NaN                 NaN
# 3                NaN                NaN          NaN                 NaN
# 4                NaN                NaN          NaN                 NaN
#
#    BootcampRecommend  ChildrenNumber  ... ResourceSoloLearn  \
# 0                NaN             NaN  ...               NaN
# ...

# %%
# Take only columns 0, 1, 2, 3, 4, 6, 7, 8, 9, 10, 11, 29, 30, 32, 36, 37, 45, 48, 56, 110, 111
# Consider using iloc
extract_df = df.iloc[:,[0, 1, 2, 3, 4, 6, 7, 8, 9, 10, 11, 29, 30, 32, 36, 37, 45, 48, 56, 110, 111]]
extract_df.head()
# Out:
#     Age  AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 0  28.0               0.0             NaN                   NaN
# 1  22.0               0.0             NaN                   NaN
# 2  19.0               0.0             NaN                   NaN
# 3  26.0               0.0             NaN                   NaN
# 4  20.0               0.0             NaN                   NaN
#
#    BootcampLoanYesNo BootcampName  BootcampPostSalary  BootcampRecommend  \
# 0                NaN          NaN                 NaN                NaN
# 1                NaN          NaN                 NaN                NaN
# 2                NaN          NaN                 NaN                NaN
# 3                NaN          NaN                 NaN                NaN
# 4                NaN          NaN                 NaN                NaN
#
#    ChildrenNumber                 CityPopulation  ...  \
# 0             NaN  between 100,000 and 1 million  ...
# ...

# %%
# Change reading 0 and 1 to No and Yes, respectively
extract_df=extract_df.replace([0 ,1], ['No', 'Yes'])
extract_df.head()
# Out:
#     Age AttendedBootcamp BootcampFinish BootcampFullJobAfter  \
# 0  28.0               No            NaN                  NaN
# 1  22.0               No            NaN                  NaN
# 2  19.0               No            NaN                  NaN
# 3  26.0               No            NaN                  NaN
# 4  20.0               No            NaN                  NaN
#
#   BootcampLoanYesNo BootcampName  BootcampPostSalary BootcampRecommend  \
# 0               NaN          NaN                 NaN               NaN
# 1               NaN          NaN                 NaN               NaN
# 2               NaN          NaN                 NaN               NaN
# 3               NaN          NaN                 NaN               NaN
# 4               NaN          NaN                 NaN               NaN
#
#   ChildrenNumber                 CityPopulation  ...  \
# 0            NaN  between 100,000 and 1 million  ...
# 1            NaN  between 100,000 and 1 million  ...
# ...

# %%
# Extract rows for only those who attended a bootcamp
attended_df = extract_df.loc[extract_df["AttendedBootcamp"] == "Yes"]
attended_df
# Out:
#         Age AttendedBootcamp BootcampFinish BootcampFullJobAfter  \
# 93     32.0              Yes            Yes                   No
# 97     26.0              Yes            Yes                  Yes
# 130    41.0              Yes            Yes                  Yes
# 159    26.0              Yes            Yes                   No
# 188    24.0              Yes             No                  NaN
# ...     ...              ...            ...                  ...
# 15539  39.0              Yes            Yes                  Yes
# 15540  24.0              Yes            Yes                  Yes
# 15541  23.0              Yes            Yes                  Yes
# 15593  29.0              Yes             No                  NaN
# 15600  28.0              Yes            Yes                  Yes
#
#       BootcampLoanYesNo              BootcampName  BootcampPostSalary  \
# 93                   No            Codify Academy                 NaN
# ...

# %%
# Create DataFrame of the different boot camps that had a significant number of attendees
# Create a DataFrame from using value_counts
bt_nm=attended_df["BootcampName"].value_counts()
bt_nm_df=pd.DataFrame(bt_nm)

bt_nm_df.reset_index(inplace=True)

bt_nm_df.columns=['BootcampName','Count']

bt_nm_df
# Out:
#                                  BootcampName  Count
# 0                            General Assembly     90
# 1                             Flatiron School     54
# 2                                Dev Bootcamp     48
# 3                               The Iron Yard     40
# 4                       Prime Digital Academy     30
# ..                                        ...    ...
# 123                                     codeU      1
# 124                       CodeMasters Academy      1
# 125                              Atlanta Code      1
# 126                         Astro Code School      1
# 127  Launch School (formerly Tealeaf Academy)      1
#
# [128 rows x 2 columns]

# %%
# Count how many attendees of each bootcamp would recommend the bootcamp
recomm = attended_df["BootcampName"].loc[extract_df["BootcampRecommend"] == "Yes"].value_counts()
recomm_df=pd.DataFrame(recomm)

recomm_df.reset_index(inplace=True)

recomm_df.columns=['BootcampName','Recommenders']

recomm_df
# Out:
#                                  BootcampName  Recommenders
# 0                            General Assembly            70
# 1                             Flatiron School            50
# 2                                Dev Bootcamp            41
# 3                               The Iron Yard            31
# 4                                Hack Reactor            27
# ..                                        ...           ...
# 111                          CodeCraft School             1
# 112                                     codeU             1
# 113                       CodeMasters Academy             1
# 114                                 HackerYou             1
# 115  Launch School (formerly Tealeaf Academy)             1
#
# [116 rows x 2 columns]

# %%
# Merge the two created data frames on the name of tbe bootcamp
merge_df = pd.merge(bt_nm_df, recomm_df, on="BootcampName", how="right")
merge_df
# Out:
#                                  BootcampName  Count  Recommenders
# 0                            General Assembly     90            70
# 1                             Flatiron School     54            50
# 2                                Dev Bootcamp     48            41
# 3                               The Iron Yard     40            31
# 4                       Prime Digital Academy     30            25
# ..                                        ...    ...           ...
# 111                      Ladies Learning Code      1             1
# 112                          CodeCraft School      1             1
# 113                                     codeU      1             1
# 114                       CodeMasters Academy      1             1
# 115  Launch School (formerly Tealeaf Academy)      1             1
#
# [116 rows x 3 columns]

# %%
# Calculate percentage of each bootcamp's students who are recommenders
# Think of what should be the numerator and the demoninator
merge_df['% Recommended']=round((merge_df['Recommenders']/merge_df['Count'])*100,2)

# Sort results in descending order
merge_df_s=merge_df.sort_values('% Recommended', ascending=False)
# Format for percentages

merge_df_s["% Recommended"] = merge_df_s["% Recommended"].map("{:.2f}%".format)
merge_df_s
# Out:
#             BootcampName  Count  Recommenders % Recommended
# 58  Grace Hopper Academy      3             3       100.00%
# 93     Founders & Coders      1             1       100.00%
# 91    The Data Incubator      1             1       100.00%
# 90           DESIGNATION      1             1       100.00%
# 89        Base10 Academy      1             1       100.00%
# ..                   ...    ...           ...           ...
# 64        We Can Code IT      3             1        33.33%
# 65              V School      3             1        33.33%
# 66        Starter League      3             1        33.33%
# 67          Coding House      3             1        33.33%
# 44        Codify Academy      4             1        25.00%
#
# [116 rows x 4 columns]

# %%
# Export to excel and remove index
merge=merge_df_s.to_excel("Output/DataCleanSummary.xls", index=False, header=True)
